# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import json, os\n",
    "import matplotlib.pyplot as plt\n",
    "import numpy as np\n",
    "from pprint import pprint\n",
    "metrics_path = '../metrics/results.json'\n",
    "with open(metrics_path) as f: m = json.load(f)\n",
    "pprint(m)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "labels = []\n",
    "clean_acc = []\n",
    "rob_acc = []\n",
    "for k,v in m.items():\n",
    "    labels.append(k)\n",
    "    clean_acc.append(v.get('clean_acc', np.nan))\n",
    "    rob_acc.append(v.get('rob_acc', np.nan))\n",
    "list(zip(labels, clean_acc, rob_acc))"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "x = np.arange(len(labels))\n",
    "w = 0.35\n",
    "fig = plt.figure(figsize=(8,4))\n",
    "plt.bar(x - w/2, clean_acc, width=w, label='Clean ACC')\n",
    "plt.bar(x + w/2, rob_acc, width=w, label='Robust ACC')\n",
    "plt.xticks(x, labels, rotation=20, ha='right')\n",
    "plt.ylabel('Accuracy')\n",
    "plt.title('Clean vs Robust Accuracy')\n",
    "plt.legend()\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
  "language_info": {"name": "python", "version": "3.x"}
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
